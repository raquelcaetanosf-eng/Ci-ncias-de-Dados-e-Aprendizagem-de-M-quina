# %% [markdown]
# <a href="https://colab.research.google.com/github/raquelcaetanosf-eng/Ci-ncias-de-Dados-e-Aprendizagem-de-M-quina/blob/main/Ciencia_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###A**ula 02/09 II – Análise e Ciência de Dados**
#
# - Visualização e interpretação de dados
# - Aula prática + resolução colaborativa de problemas
# - Criar gráficos e interpretar informações obtidas dos dados
# - Dashboard ou conjunto de visualizações comentadas
#
# Nome: Raquel Caetano | Sistemas de Informação
#
# Referência
# CARVALHO, André Carlos de; MENEZES, Angelo; BONIDIA, Robson. Ciência de Dados — Fundamentos e
# Aplicações. Capítulo “Python para Ciência de Dados”. Disponível em: https://bonidia.github.io/cd-
# fundamentos/cp2.html. Acesso em: 2 set. 2026.

# %%
import pandas as pd
prioridades = pd.Series(["Alta", "Média", "Baixa"], name="prioridade")
exemplo = pd.DataFrame({"id": ["CH001", "CH002"], "tempo": [3.5, 12.0]})

# %%
df = pd.read_csv("chamados_suporte_ti.csv")
df.head()
df.tail(3)
df.shape
df.columns
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_chamado             18 non-null     object
#  1   data_abertura          18 non-null     object
#  2   setor                  18 non-null     object
#  3   categoria              18 non-null     object
#  4   prioridade             18 non-null     object
#  5   status                 18 non-null     object
#  6   tempo_resolucao_horas  16 non-null     float64
#  7   satisfacao             16 non-null     float64
#  8   reaberto               18 non-null     object
#  9   analista               18 non-null     object
# dtypes: float64(2), object(8)
# memory usage: 1.5+ KB
#        tempo_resolucao_horas  satisfacao
# count              16.000000   16.000000
# mean               23.000000    3.625000
# std                29.648496    1.310216
# ...

# %%
df["setor"]
df[["id_chamado", "setor"]]
df.loc[0:2, ["id_chamado", "setor"]]
df.iloc[0:3, 0:2]
# Out:
#   id_chamado data_abertura
# 0      CH001    2026-08-20
# 1      CH002    2026-08-20
# 2      CH003    2026-08-21

# %%
df[df["prioridade"] == "Alta"]
df[(df["prioridade"] == "Alta") & (df["status"] == "Resolvido")]
df[df["categoria"].isin(["Acesso", "Rede"])]
# Out:
#    id_chamado data_abertura        setor categoria prioridade        status  \
# 0       CH001    2026-08-20   Financeiro    Acesso       Alta     Resolvido
# 4       CH005    2026-08-22           RH    Acesso      Média  Em andamento
# 5       CH006    2026-08-22    Acadêmico      Rede       Alta     Resolvido
# 9       CH010    2026-08-24  Laboratório      Rede    Crítica     Resolvido
# 11      CH012    2026-08-25    Acadêmico    Acesso      Baixa     Resolvido
# 12      CH013    2026-08-26   Biblioteca      Rede      Média     Resolvido
# 15      CH016    2026-08-27   Financeiro    Acesso      Baixa     Resolvido
#
#     tempo_resolucao_horas  satisfacao reaberto analista
# 0                     3.5         5.0      Não      Ana
# 4                     NaN         NaN      Não    Diego
# 5                     9.5         2.0      Sim    Bruno
# 9                     6.0         2.0      Sim    Bruno
# 11                   10.0         5.0      Não    Diego
# ...

# %%
df["data_abertura"] = pd.to_datetime(df["data_abertura"])
df["tempo_dias"] = df["tempo_resolucao_horas"] / 24
df["satisfacao"] = df["satisfacao"].astype("Int64")

# %%
df["status"].value_counts()
df["tempo_resolucao_horas"].mean()
df.groupby("categoria")["tempo_resolucao_horas"].mean().sort_values(ascending=False)
# Out:
# categoria
# Sistema lento      47.750000
# Impressora         30.000000
# Acesso             21.833333
# Hardware           18.000000
# Rede               11.166667
# Erro de sistema     4.000000
# Name: tempo_resolucao_horas, dtype: float64

# %% [markdown]
# ###Conclusão
#
# Script finaliza mostrando que o suporte atingiu 68,8% de sucesso no SLA (11 chamados) e aponta como gargalo "Sistema lento", puxada por um ticket atípico de 120 horas que precisa de auditoria.
