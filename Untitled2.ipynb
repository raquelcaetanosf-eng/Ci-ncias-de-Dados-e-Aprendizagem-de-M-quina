# %% [markdown]
# <a href="https://colab.research.google.com/github/raquelcaetanosf-eng/Ci-ncias-de-Dados-e-Aprendizagem-de-M-quina/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
cidades = pd.DataFrame(
[
['Paraná', 'Londrina', 575377, 1356.00],
['São Paulo', 'São Carlos', 254484, 1508.00],
['Santa Catarina', 'Florianópolis', 508826, 1798.00],
['Paraná', 'Curitiba', 1963726, 2293.00],
['São Paulo', 'Campinas', 1223237, 1710.00]
], columns=['Estado', 'Cidade', 'Habitantes', 'Salário-Médio'])
cidades
# Out:
#            Estado         Cidade  Habitantes  Salário-Médio
# 0          Paraná       Londrina      575377         1356.0
# 1       São Paulo     São Carlos      254484         1508.0
# 2  Santa Catarina  Florianópolis      508826         1798.0
# 3          Paraná       Curitiba     1963726         2293.0
# 4       São Paulo       Campinas     1223237         1710.0

# %%
import pandas as pd

df = pd.read_csv('qualidade_vinho.csv', sep=',', header=0)

# Se você estiver usando um Jupyter Notebook/Google Colab, apenas df.head(2) já mostra a tabela.
# Se estiver rodando em um arquivo .py comum (como no VS Code), use o print:
print(df.head(2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2230/983291717.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('qualidade_vinho.csv', sep=',', header=0)
#       4
#       5 # Se você estiver usando um Jupyter Notebook/Google Colab, apenas df.head(2) já mostra a tabela.
#
# ...
